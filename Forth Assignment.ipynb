# %%
""" Assignment # 4
Start Working Date is 27/11/019
Created by Vikash
Email : vikashbaria4@gmail.com

Q1 : Use a dictionary to store information about a person you know. Store their first name, last name, age,
and the city in which they live. You should have keys such as first_name, last_name, age, and city. Print
each piece of information stored in your dictionary. Add a new key value pair about qualification then
update the qualification value to high academic level then delete it.

"""


person ={
    
    "first_name":"vikash",
    "last_name":"harjeewan",
    "age":"25",
    "city":"karachi"
}

# Printing type for check type of data 
#print(type(person))
print("Below mentioned existing dictionary\n-----------------------------------------\n")
print(person)
print("\nAdded new key with value in dictionary from update function\n-----------------------------------------")

person.update({"qualification":"intermedaite"})
print(person)
print("\nUpdating the value of qualification key in dictionary\n-----------------------------------------\n")
print("Currently the value of qualification is "+  person['qualification'])
person['qualification'] = "B.COM"
print("\n\t HERE IS THE UPDATED DICTIONARY WITH UPDATED VALUES OF QUALIFICATION.\n")
print(person)
del person['qualification']

print("\n\t DELETED THE KEY OF QUALIFICATION AND BELOW MENTIONED\n")

print(person)
# Out:
# Below mentioned existing dictionary
# -----------------------------------------
#
# {'first_name': 'vikash', 'last_name': 'harjeewan', 'age': '25', 'city': 'karachi'}
#
# Added new key with value in dictionary from update function
# -----------------------------------------
# {'first_name': 'vikash', 'last_name': 'harjeewan', 'age': '25', 'city': 'karachi', 'qualification': 'intermedaite'}
#
# Updating the value of qualification key in dictionary
# -----------------------------------------
#
# Currently the value of qualification is intermedaite
#
# 	 HERE IS THE UPDATED DICTIONARY WITH UPDATED VALUES OF QUALIFICATION.
#
# {'first_name': 'vikash', 'last_name': 'harjeewan', 'age': '25', 'city': 'karachi', 'qualification': 'B.COM'}
#
# 	 DELETED THE KEY OF QUALIFICATION AND BELOW MENTIONED
#
# {'first_name': 'vikash', 'last_name': 'harjeewan', 'age': '25', 'city': 'karachi'}

# %%
"""
I have created above program but somebody told me show dictionary values and key in new lines.
So I have created a function which will show key and values on single line



Q1 : Use a dictionary to store information about a person you know. Store their first name, last name, age,
and the city in which they live. You should have keys such as first_name, last_name, age, and city. Print
each piece of information stored in your dictionary. Add a new key value pair about qualification then
update the qualification value to high academic level then delete it.

"""
persons ={
    
    "first_name":"vikash",
    "last_name":"harjeewan",
    "age":"25",
    "city":"karachi"
}

def print_dic_values_and_key(dicti_name):
    for keys,values in dicti_name.items():
        print(keys + " : " +values)
# Printing type for check type of data 
#print(type(person))
print("Below mentioned existing dictionary\n-----------------------------------------\n")  
print_dic_values_and_key(persons)  
print("\nAdded new key with value in dictionary from update function\n-----------------------------------------")
persons.update({"qualification":"intermedaite"})
print_dic_values_and_key(persons) 
print("\nUpdating the value of qualification key in dictionary\n-----------------------------------------\n")
print("Currently the value of qualification is "+  persons['qualification'])
persons['qualification'] = "B.COM"
print("\n\t HERE IS THE UPDATED DICTIONARY WITH UPDATED VALUES OF QUALIFICATION.\n")
print_dic_values_and_key(persons) 
del persons['qualification']

print("\n\t DELETED THE KEY OF QUALIFICATION AND BELOW MENTIONED\n")

print_dic_values_and_key(persons)
# Out:
# Below mentioned existing dictionary
# -----------------------------------------
#
# first_name : vikash
# last_name : harjeewan
# age : 25
# city : karachi
#
# Added new key with value in dictionary from update function
# -----------------------------------------
# first_name : vikash
# last_name : harjeewan
# age : 25
# city : karachi
# qualification : intermedaite
#
# Updating the value of qualification key in dictionary
# -----------------------------------------
#
# Currently the value of qualification is intermedaite
#
# 	 HERE IS THE UPDATED DICTIONARY WITH UPDATED VALUES OF QUALIFICATION.
#
# first_name : vikash
# last_name : harjeewan
# age : 25
# city : karachi
# qualification : B.COM
#
# 	 DELETED THE KEY OF QUALIFICATION AND BELOW MENTIONED
#
# first_name : vikash
# last_name : harjeewan
# age : 25
# city : karachi

# %%
"""
Q2 : Make a dictionary called cities. Use the names of three cities as keys in your dictionary. Create a
dictionary of information about each city and include the country that the city is in, its approximate
population, and one fact about that city. The keys for each city’s dictionary should be something like
country, population, and fact. Print the name of each city and all of the information you have stored
about it.
"""
 

cities = {
    "Bangkok": {
        "country":"Thailand",
        "population": "8.281",
        "fact": "Bangkok has the longest city name in the World.",
        "Most Visited ":"20.05 million"
        },
    
    "London": {
        "country":"Capital of England",
        "population": "8.9 million",
        "fact": "Big Ben Is Not The Name For The Tower",
        "Most Visited ":"19.83 million"
        },
    
    "Paris": {
        "country":"France",
        "population": "2.141 million",
        "fact": "Paris was originally a Roman City called “Lutetia.",
        "Most Visited ":"17.44 million"
        
        }
}
print("Currently we have 3 cities database which is below mentioned \n")
for cities_name in cities.keys():
    print(cities_name)
city =input("\nEnter above mentioned city name to fetch data from  ")
flag = False
for city_key,city_val in cities.items():
    if city_key == city:
        flag = True
        break
if(flag):
    print(str(city_key) + " : " + str(city_val) )
else:
    print("Right Now we dont have that country.")
# Out:
# Currently we have 3 cities database which is below mentioned
#
# Bangkok
# London
# Paris
#
# Enter above mentioned city name to fetch data from  London
# London : {'country': 'Capital of England', 'population': '8.9 million', 'fact': 'Big Ben Is Not The Name For The Tower', 'Most Visited ': '19.83 million'}

# %%
"""
Q3 : A movie theater charges different ticket prices depending on a person’s age. If a person is under the age
of 3, the ticket is free; if they are between 3 and 12, the ticket is $10; and if they are over age 12, the
ticket is $15. Write a loop in which you ask users their age, and then tell them the cost of their movie
ticket.
"""

print("Welcome to online ticket booking system\n--------------------------------\n\nWe have different prices of tickets according your age")
age = int(input("\nPlease enter Your Age "))
for i in range(0,3):
    if age <= 3:
        print(" \nYour Ticket is Free.")
        break
    elif age <= 12 and age >= 3:
        print(" \nYour Ticket price is 10$.")
        break        
    elif age >= 12:
        print(" \nYour Ticket price is $15.")
        break
# Out:
# Welcome to online ticket booking system
# --------------------------------
#
# We have different prices of tickets according your age
#
# Please enter Your Age 2
#
# Your Ticket is Free.

# %%
"""
Question4:
Write a function called favorite_book() that accepts one parameter, title. The function should print a
message, such as One of my favorite books is Alice in Wonderland. Call the function, making sure to
include a book title as an argument in the function call.

"""
print("Welcome to Read Online Books\n--------------------------------------------\n")
book_details = {
    "Ulysses": 
    {
        "Author":"James Joyce",
        "Publisher": "Sylvia Beach",
        "Publication date": "2 February 1922.",
        "Total Pages ":"730"
    },
    "Don Quixote": 
    {
        "Author":"Miguel de Cervantes",
        "Publisher": "Francisco de Robles",
        "Publication date": "1605 (Part One) 1615 (Part Two)",
        "Total Pages ":"863"
    },
    "Lolita": 
    {
        "Author":"Vladimir Nabokov",
        "Publisher": "Olympia Press",
        "Publication date": "1955",
        "Total Pages ":"336"
        
    }
}
input_book_name = input("Enter Your Book Name = ")

def find_book(input_book_name):
    flag = False 
    for book_key,book_values in book_details.items():
        if book_key == input_book_name:
            flag =  True
            break
    if(flag):            
        print("\nThanks for your input here is the details of your provided book name\n----------------------------------------------\n")
        print(str(book_key) + " " + str(book_values) )
    else:
        print("Thanks for your input but "+ input_book_name +" not available on store")    
    
            
find_book(input_book_name)
# Out:
# Welcome to Read Online Books
# --------------------------------------------
#
# Enter Your Book Name = Lolita
#
# Thanks for your input here is the details of your provided book name
# ----------------------------------------------
#
# Lolita {'Author': 'Vladimir Nabokov', 'Publisher': 'Olympia Press', 'Publication date': '1955', 'Total Pages ': '336'}

# %%
import random
print("WELCOME HERE TO CHECK YOUR LUCK")
total_score = 0
Flag = False
for x in range(0,3):
    number = random.randint(1, 2)
    user_number =input("Enter One Number which is between 1 to 30 ")
    if  str(user_number) == str(number):
        total_score += 10
        Flag = True
    if(Flag):
        print("Random Number is generated " + str(number) + " and Your number is "+ str(user_number))
        
    else:
        print("Your input is wrong and the random number was " + str(number))
print("Your total score is " + str(total_score))
# Out:
# WELCOME HERE TO CHECK YOUR LUCK
# Enter One Number which is between 1 to 30 2
# Random Number is generated 2 and Your number is 2
# Enter One Number which is between 1 to 30 2
# Random Number is generated 2 and Your number is 2
# Enter One Number which is between 1 to 30 2
# Random Number is generated 1 and Your number is 2
# Your total score is 20

# %%
"""
Q3 : A movie theater charges different ticket prices depending on a person’s age. If a person is under the age
of 3, the ticket is free; if they are between 3 and 12, the ticket is $10; and if they are over age 12, the
ticket is $15. Write a loop in which you ask users their age, and then tell them the cost of their movie
ticket.
"""

# First input number of persons
# Then input age for all persons 
# Then check if age is below 3 and number of persons is only one then its will be print on screen only alone kid are not allow.
# if the kid is below 3 and the persons is more than one its will show you the total cost except 


print("Welcome to online ticket booking system\n--------------------------------\n\nWe have different prices of tickets according your age")

persons_number =int(input("\nHow many persons "))


print("\nWe charge ticket cost according the age\n")
total_price = 0
for i in range(1,persons_number+1):
    age = int(input("\nPlease Enter Age "))
    if age <= 3 and persons_number != 1:
        print(" \nWe don't charge for below 3 years old.")
    elif age <= 3 and persons_number == 1:
        print(" \nWe don't allow alone kid on cinema.")    
    elif age <= 12 and age >= 3:
        print("We charged more than 3 years old and below 12 years old the ticket cost is 10$")
        total_price +=10
                
    elif age >= 12:
        print("We charged more than 12 years old the ticket cost is 12$")
        total_price +=12
        
print("\n------------------------------------------\nYour Total Cost of Tickets is " + str(total_price)+"$")
# Out:
# Welcome to online ticket booking system
# --------------------------------
#
# We have different prices of tickets according your age
#
# How many persons 1
#
# We charge ticket cost according the age
#
#
# Please Enter Age 1
#
# We don't allow alone kid on cinema.
#
# ------------------------------------------
# Your Total Cost of Tickets is 0$
